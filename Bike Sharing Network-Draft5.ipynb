# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl
import matplotlib.colors as colors

import networkx as nx
import community as community_louvain

import folium
from folium.plugins import HeatMap
from folium.plugins import MarkerCluster
from collections import Counter

from datetime import datetime
import calendar
import holidays
import datetime

import os
import requests
from zipfile import ZipFile
from io import BytesIO

import ipywidgets as widgets
from IPython.display import display, clear_output, IFrame
import time
import asyncio

from html2image import Html2Image

# %% [markdown]
# ### Download and open the dataset

# %%
base_url = "https://s3.amazonaws.com/hubway-data/"

def download_and_unzip(year, month):
    if year < 2018 or (year == 2018 and month < 5):
        brand = 'hubway'
    else:
        brand = 'bluebikes'

    filename = f"{year}{month:02d}-{brand}-tripdata.zip"
    filepath = os.path.join(f"{year}{month:02d}-{brand}-tripdata")  # replace with your local path

    # Download if the file does not exist in the device
    if not os.path.exists(filepath):
        print(f"Downloading {filename}...")
        response = requests.get(base_url + filename, stream=True)
        response.raise_for_status()
        
        # Unzip
        with ZipFile(BytesIO(response.content)) as thezip:
            print("Unzipping...")
            thezip.extractall(f"{year}{month:02d}-{brand}-tripdata") 
            print(f"Unzipped to {year}{month:02d}-{brand}-tripdata")
    else:
        print(filename,"already exists.")
    
    df_full = pd.read_csv(f"{year}{month:02d}-{brand}-tripdata/{year}{month:02d}-{brand}-tripdata.csv")
    df_full.replace('\\N', np.nan, inplace=True)
    df_full = df_full.dropna() #if the data contains NA, drop the row
    
    # Change the name of the column so that it is similar in all brand name
    if brand == 'bluebikes':
        df_full.rename(columns={'started_at': 'starttime'}, inplace=True)
        df_full.rename(columns={'ended_at': 'stoptime'}, inplace=True)
        df_full.rename(columns={'start_station_id': 'start station id'}, inplace=True)
        df_full.rename(columns={'end_station_id': 'end station id'}, inplace=True)
        df_full.rename(columns={'start_lat': 'start station latitude'}, inplace=True)
        df_full.rename(columns={'start_lng': 'start station longitude'}, inplace=True)
        df_full.rename(columns={'end_lat': 'end station latitude'}, inplace=True)
        df_full.rename(columns={'end_lng': 'end station longitude'}, inplace=True)
        df_full.rename(columns={'member_casual': 'usertype'}, inplace=True)
               
    return(df_full)

# %% [markdown]
# ### Filter based on date and time

# %%
def filter_date_time(df, year, month, start_day, start_hour, start_minute, end_day, end_hour, end_minute):
    
   # Define holidays for Massachusetts, USA
    usa_holidays = holidays.UnitedStates(years=year, state='MA')
    
    # Ensure starttime and stoptime are in datetime format
    df['starttime'] = pd.to_datetime(df['starttime'])
    df['stoptime'] = pd.to_datetime(df['stoptime'])
    
    # Calculate trip duration in seconds
    if 'tripduration' not in df.columns:
        df['tripduration'] = (df['stoptime'] - df['starttime']).dt.total_seconds()
    
    # Filter trips within the specified time range
    filtered_data = df[
        (df['starttime'].dt.year == year) &
        (df['starttime'].dt.month == month) &
        (df['starttime'].dt.day >= start_day) & 
        (df['starttime'].dt.day <= end_day) &  # Ensure start and stop times fall within the same day
        (df['starttime'].dt.hour >= start_hour) &  # Starting at start_hour
        (df['starttime'].dt.minute >= start_minute) &  # Starting at or after start_minute
        (
            (df['stoptime'].dt.date == df['starttime'].dt.date) &  # Stop time is on the same day as start time
            (
                (df['starttime'].dt.hour < end_hour)   # Ending before end_hour
                # ((df['starttime'].dt.hour == end_hour-1) & (df['starttime'].dt.minute <= end_minute))  # Ending at or after end_minute
            )
        ) &
        (df['starttime'].dt.dayofweek >= 0) &  # Weekdays only
        (df['starttime'].dt.dayofweek <= 4) &  # Weekdays only
        (~df['starttime'].dt.date.isin(usa_holidays)) &
        (df['tripduration'] > 60) &  # Longer than 60 seconds
        (df['tripduration'] <= 3600)  # No longer than 3600 seconds
    ]
    
    filtered_data.reset_index(drop=True, inplace=True)
      
    return filtered_data

# %% [markdown]
# ### Full function filtering and information extraction

# %%
def initial_cleaning (month, year, start_hour, end_hour):
    '''
    INPUT
    month      : Integer signify the month of analysis
    year       : Integer signify the year of analysis
    start_hour : Integer signify the start hour of analysis 
    end_hour   : Integer signify the end hour of analysis
    
    OUTPUT 
    data_filt    : Dataframe containing complete data of the trips that already filtered 
    tc           : Dataframe containing information regarding the number of trips between stations 
    stations_loc : Dataframe containing information about the latitude and longitude of each stations 
    '''
    # Download/open the file 
    bsn_full = download_and_unzip(int(year), int(month))
    
    # Filter date and time 
    start_year = year
    start_month = month
    end_year = year
    end_month = month

    start_day = 1
    _, end_day = calendar.monthrange(year, month) # automatically take the last date of the month
    start_minute = 0
    end_minute = 59
    
    end_hour = end_hour

    data_filt = filter_date_time(bsn_full, year, month, start_day, start_hour, start_minute, end_day, end_hour, end_minute)
    
    # Filter self loop, member only
    data_filt = data_filt[data_filt['start station id'] != data_filt['end station id']]
    data_filt = data_filt[data_filt['usertype'].isin(['Subscriber', 'member'])]
    data_filt.reset_index(drop=True, inplace=True)
    
    # Trip_counts
    tc = data_filt.groupby(['start station id', 'end station id','start station latitude', 'start station longitude', 
                            'end station latitude', 'end station longitude']).size().reset_index(name='trip_count')
    
    # Location of the stations
    start_stations = data_filt[['start station id', 'start station latitude', 'start station longitude']].copy()
    end_stations = data_filt[['end station id', 'end station latitude', 'end station longitude']].copy()

    start_stations.columns = ['station id', 'latitude', 'longitude']
    end_stations.columns = ['station id', 'latitude', 'longitude']

    stations_loc= pd.concat([start_stations, end_stations], ignore_index=True)
    stations_loc = stations_loc.drop_duplicates(subset='station id').reset_index(drop=True)
    stations_loc['station id'] = stations_loc['station id']#.astype(int)
    stations_loc = stations_loc.sort_values(by='station id', ascending=True).reset_index(drop=True)# Delete any duplicates
    
    return data_filt, tc, stations_loc

# %% [markdown]
# For the current simple analysis, September is picked to be the best month because campuses are active and it is the period with less rain.

# %%
starth = 7
endh = 8
mon = 9 
year1 = 2016
year2 = 2018

# %%
data_16, trip_counts_16, stations_loc_16 = initial_cleaning (month = mon, year = year1, start_hour = starth , end_hour = endh)
# Out:
# 201609-hubway-tripdata.zip already exists.

# %%
data_18, trip_counts_18, stations_loc_18 = initial_cleaning (month = mon, year = year2, start_hour = starth , end_hour = endh)
# Out:
# 201809-bluebikes-tripdata.zip already exists.

# %% [markdown]
# ### Preliminary Statisical Analysis Year Before and After

# %%
dif_num_trips = len(data_18) - len(data_16)
print('Different number of trips are', dif_num_trips, 'trips')
# Out:
# Different number of trips are 2228 trips

# %%
data_16['tripduration_minutes'] = data_16['tripduration'] / 60
data_18['tripduration_minutes'] = data_18['tripduration'] / 60

bins = range(0, 60, 2)

plt.figure(figsize=(12, 6))
plt.hist(data_18['tripduration_minutes'], bins=bins, alpha=0.5, label='2018', color='red', edgecolor='black')
plt.hist(data_16['tripduration_minutes'], bins=bins, alpha=0.5, label='2016', color='blue', edgecolor='black')
plt.title('Histogram of Trip Durations (in minutes) for 2016 and 2018')
plt.xlabel('Trip Duration (minutes)')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.xlim(1,60)
plt.grid(True)
plt.show()

# %%
# Plot normalized
plt.figure(figsize=(12, 6))
hist_16, bins_16, _ = plt.hist(data_16['tripduration_minutes'], bins=bins, alpha=0.5, label='2016', color='blue', edgecolor='black', density=True)
hist_18, bins_18, _ = plt.hist(data_18['tripduration_minutes'], bins=bins, alpha=0.5, label='2018', color='red', edgecolor='black', density=True)
plt.title('Normalized Histogram of Trip Durations (in minutes) for 2016 and 2018')
plt.xlabel('Trip Duration (minutes)')
plt.ylabel('Density')
plt.legend(loc='upper right')
plt.grid(True)
plt.xlim(1, 60)
plt.show()

# %%
old_stations_18 = stations_loc_18[stations_loc_18['station id'].isin(stations_loc_16['station id'])]
new_stations_18 = stations_loc_18[~stations_loc_18['station id'].isin(stations_loc_16['station id'])]

# %%
from branca.element import Template, MacroElement
map_center = [new_stations_18['latitude'].mean(), new_stations_18['longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=11, tiles='CartoDB positron')

# Add markers for each new station
for _, station in new_stations_18.iterrows():

    folium.CircleMarker(
            location=[station['latitude'], station['longitude']],
            radius=3,
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.7,
        ).add_to(m)

for _, station in old_stations_18.iterrows():

    folium.CircleMarker(
            location=[station['latitude'], station['longitude']],
            radius=3,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.7,
        ).add_to(m)

legend_html = f'''
     <div style="position: fixed; 
                 top: 10px; right: 20px; width: 150px; height: 80px; 
                 background-color: white; border:2px solid grey; z-index:9999; font-size:14px;
                 ">
     &nbsp; <b>Legend</b> <br>
     &nbsp; <i class="fa fa-circle" style="color:red"></i>&nbsp; New Stations <br>
     &nbsp; <i class="fa fa-circle" style="color:blue"></i>&nbsp; Old Stations
     </div>
     '''

m.get_root().html.add_child(folium.Element(legend_html))
# Add the legend to the map
legend = MacroElement()
legend._template = Template(legend_html)
m.get_root().add_child(legend)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eab313704403c88598a6a80b9e2b0d92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#      &lt;div style=&quot;position: fixed;
#                  top: 10px; right: 20px; width: 150px; height: 80px;
#                  background-color: white; border:2px solid grey; z-index:9999; font-size:14px;
#                  &quot;&gt;
#      &amp;nbsp; &lt;b&gt;Legend&lt;/b&gt; &lt;br&gt;
#      &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt;&amp;nbsp; New Stations &lt;br&gt;
#      &amp;nbsp; &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:blue&quot;&gt;&lt;/i&gt;&amp;nbsp; Old Stations
#      &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eab313704403c88598a6a80b9e2b0d92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eab313704403c88598a6a80b9e2b0d92 = L.map(
#                 &quot;map_eab313704403c88598a6a80b9e2b0d92&quot;,
#                 {
#                     center: [42.345066197183094, -71.0916309859155],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_586ea2fa70344cd7aae6bdbf87cff780 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_586ea2fa70344cd7aae6bdbf87cff780.addTo(map_eab313704403c88598a6a80b9e2b0d92);
#
#
#             var circle_marker_e4b888c5a86a691cf0a5acdbb498cb32 = L.circleMarker(
#                 [42.3405, -71.0814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_eab313704403c88598a6a80b9e2b0d92);
#
#
#             var circle_marker_19cf490170808a094fcaef5e431a8c7e = L.circleMarker(
#                 [42.3328, -71.1162],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_eab313704403c88598a6a80b9e2b0d92);
#
#
#             var circle_marker_fbb3ca5d9af7de7255df38af4cf849d6 = L.circleMarker(
#                 [42.3658, -71.077],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_eab313704403c88598a6a80b9e2b0d92);
#
#
#             var circle_marker_16dec680957fef5e3df9062361bb29d4 = L.circleMarker(
#                 [42.3365, -71.099],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_eab313704403c88598a6a80b9e2b0d92);
#
#
#             var circle_marker_54b2c7fd7bb09bc8aa85dbb71daaf40c = L.circleMarker(
#                 [42.3909, -71.1096],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_eab313704403c88598a6a80b9e2b0d92);
#
#
#             var circle_marker_1f0fe09a2053698695c5efc6d511c9be = L.circleMarker(
#                 [42.3532, -71.0482],
#                 {&quot;bubblingMouseEvents&quot;: t

# %% [markdown]
# ### Network of the Bike Sharing

# %%
def create_network(trip_count_df, stations_locs, plot=False):
    '''
    INPUT 
    trip_count_df  : Dataframe containing the start station, end station, and trip count 
    stations_locs  : Dataframe containing the stations and its location coordinates
    
    OUPUT
    BSN     : Bidirectional graph 
    UNDIR   : Undirected graph
    adj_df  : Dataframe of the adjacency matrix of the bidirectional graph
    '''
    # Create Bidirectional graph
    BSN = nx.DiGraph()

    # Add edges for everytrip between the nodes(stations)
    for _, row in trip_count_df.iterrows():
        BSN.add_edge((row['start station id']), (row['end station id']), weight=(row['trip_count']))
        
    # Calculate the adjacency matrix
    adj_mat = nx.adjacency_matrix(BSN)
    # Reformating to pandas dataframe
    adj_df = pd.DataFrame(adj_mat.todense().astype(int), index=BSN.nodes(), columns=BSN.nodes()) 
    
    # Create the undirected network with the edges only register if exist both direction and the weight is the sum of both weights
    UNDIR = nx.Graph()
    for u, v, data in BSN.edges(data=True):
        
        #### Normal Undirected
        if UNDIR.has_edge(u, v):
            # If the edge already exists in the undirected graph, add the weight
            UNDIR[u][v]['weight'] += data['weight']
        else:
            # If the edge doesn't exist, create it with the current weight
            UNDIR.add_edge(u, v, weight=data['weight'])
    
    if plot == True:
        plt.figure(figsize=(17, 17)) 

        # pos = nx.kamada_kawai_layout(BSN)  # layout option 1
        pos = {row['station id']: (row['longitude'], row['latitude']) for idx, row in stations_locs.iterrows()} #layout based on coordinates
        # nx.draw(BSN, pos, with_labels=True, node_size=500, node_color='lightblue', arrows=True, edge_color='grey', alpha=1)
        nx.draw_networkx_nodes(BSN, pos, node_size=500, node_color='lightblue')
        nx.draw_networkx_edges(BSN, pos, edge_color='grey', arrows=True, alpha=0.2)
        # nx.draw_networkx_labels(BSN, pos)

        plt.axis('off')
        plt.title('Network of the Bike Sharing')

        plt.show()
    
    return BSN, UNDIR, adj_df

# %%
BSN16, UNDIR16, adj16 = create_network(trip_counts_16, stations_loc_16, plot=False)

# %%
BSN18, UNDIR18, adj18 = create_network(trip_counts_18, stations_loc_18, plot=False)

# %%
print("Sanity check if the number of trip after data in the adjacency matrix match of that in the trips database:", adj16.sum().sum() == len(data_16))
# Out:
# Sanity check if the number of trip after data in the adjacency matrix match of that in the trips database: True

# %%
print("Sanity check if the number of trip before data in the adjacency matrix match of that in the trips database:", adj18.sum().sum() == len(data_18))
# Out:
# Sanity check if the number of trip before data in the adjacency matrix match of that in the trips database: True

# %% [markdown]
# ## Analysis 1 -- Community Comparison

# %% [markdown]
# #### Create Community - Louvain Algorithm

# %% [markdown]
# First, find the communities using the Louvain algorithm
#
# Threshold : stopping criterion
#            If moving a node results in a modularity gain that is smaller than the threshold,
#            the algorithm concludes that it cannot meaningfully increase the modularity by further moves.
#            When the modularity gain across all nodes is below this threshold, the algorithm stops.
#
# Resolution : If resolution is less than 1, the algorithm favors larger communities. Greater than 1 favors smaller communities

# %%
# Function to find the best resolutions 
def com_finder (network,resolutions_range, plot=False):
    
    '''
    INPUT 
    network           : NetworkX format of Network 
    resolutions_range : List of possible values of resolution
    
    OUTPUT
    best_mod     : Value of the highest modularity 
    best_res     : Best resolution that produce best modularity
    commmunities : The list of nodes of communities 
    '''

    modularity_scores = []

    for res in resolutions_range:
        coms = nx.community.louvain_communities(network, weight='weight', resolution=res, threshold=1e-8, seed=123123)
        modularity = nx.community.modularity(network, coms, weight='weight')
        modularity_scores.append(modularity)
        
    best_mod = np.max(modularity_scores)
    best_res = resolutions_range[np.argmax(modularity_scores)]
    print("Best resolution is on", best_res, "with the value of modularity is", np.round(best_mod,2))
    
    communities = nx.community.louvain_communities(network, weight='weight',resolution=best_res, threshold=1e-8, seed=123123)
        
    if plot:    
        plt.figure(figsize=(10, 5))
        plt.plot(resolutions_range, modularity_scores, marker='o', color='red')
        plt.title('Modularity vs. Resolution')
        plt.xlabel('Resolution')
        plt.ylabel('Modularity Score')
        plt.grid(True)
        plt.show()
        
    return best_mod, best_res, communities

# %%
# bmod16, bres16, commun16 = com_finder(BSN16, resolutions_range = [0.2,0.5,0.8,0.9,1,1.1,1.2,1.5,1.8], plot=True)
bmod16, bres16, commun16 = com_finder(BSN16, resolutions_range = [1], plot=False)
# Out:
# Best resolution is on 1 with the value of modularity is 0.38

# %%
# bmod18, bres18, commun18 = com_finder(BSN18, resolutions_range = [0.2,0.5,0.8,0.9,1,1.1,1.2,1.5,1.8], plot=True)
bmod18, bres18, commun18 = com_finder(BSN18, resolutions_range = [1], plot=False)
# Out:
# Best resolution is on 1 with the value of modularity is 0.36

# %% [markdown]
# ### Plotting of the communities

# %%
# Coordinates of Galileo Galileo Way, Broadway Street
gal_way = [(42.364808, -71.089398), (42.365852, -71.089163),(42.366154, -71.088719),(42.366319, -71.088180)]
bdwy_str = [(42.364808, -71.089398), (42.364037, -71.087621)]

# %%
# Coordinates of Cambridge Street and Oxford Street 
cam_str = [(42.373918, -71.102282),(42.374924, -71.110130),(42.375454, -71.114163)]
ox_str = [(42.386056, -71.116185),(42.385192, -71.116162),(42.384312, -71.116105),(42.383633, -71.116101),(42.378770, -71.116624),(42.376446, -71.115758)]

# %%
# Coordinates of Beacon street
beacon_str = [(42.386197, -71.116081),(42.384711, -71.114328),(42.383195, -71.112392),(42.380188, -71.108679),(42.378308, -71.106383),
              (42.374322, -71.101545)]

# %%
colors = ['red', 'blue', 'green', 'yellow', 'purple', 'orange', 'pink', 'gray', 'brown', 'cyan',
     'magenta', 'lime', 'maroon', 'olive', 'navy', 'teal', 'aqua', 'fuchsia', 'silver'
]

# colors = ['cyan', 'lime', 'olive', 'navy', 'teal', 'aqua', 'fuchsia', 'silver', 'brown']

# %%
def create_community_color_df(communities, colors):
    """
    INPUT
    communities : Each set contains the node IDs of a community.
    colors      : List of strings containing the colors to assign to each community.

    OUPUT
    community_color_df : DataFrame with columns containing the nodes, the community they belong, and the color associated
    """
    sorted_communities = sorted(communities, key=lambda x: min(x))
    
    community_color_data = []
    for idx, community in enumerate(sorted_communities):
        color = colors[idx % len(colors)]
        for node in sorted(community):
            community_color_data.append((node, idx, color))
    
    community_color_df = pd.DataFrame(community_color_data, columns=['Node', 'Community', 'Color'])
    
    if pd.api.types.is_float_dtype(community_color_df['Node']):
        community_color_df['Node'] = community_color_df['Node'].astype(int)  
    
    return community_color_df

# %%
# def create_community_color_df(communities, colors):
#     """
#     INPUT:
#     communities : List of sets, where each set contains the node IDs of a community.
#     colors      : List of strings containing the colors to assign to each community.

#     OUTPUT:
#     community_color_df : DataFrame
#     """

#     special_nodes_colors = {245:'magenta', 90 :'purple', 100: 'pink', 212: 'orange', 69:'green', 40 : 'yellow', 108: 'blue', 178: 'red'}
    
#     sorted_communities = sorted(communities, key=lambda x: min(x))
#     node_to_community = {node: idx for idx, community in enumerate(sorted_communities) for node in community}
#     community_to_color = {}

#     # Assign special colors to specified nodes' communities
#     for node, color in special_nodes_colors.items():
#         if node in node_to_community:
#             community_id = node_to_community[node]
#             community_to_color[community_id] = color

#     # Assign other colors to the remaining communities
#     color_index = 0
#     for idx in range(len(sorted_communities)):
#         if idx not in community_to_color:
#             community_to_color[idx] = colors[color_index % len(colors)]
#             color_index += 1

#     # Build the DataFrame
#     community_color_data = []
#     for community_id, community_nodes in enumerate(sorted_communities):
#         color = community_to_color[community_id]
#         for node in sorted(community_nodes):
#             community_color_data.append((node, community_id, color))

#     community_color_df = pd.DataFrame(community_color_data, columns=['Node', 'Community', 'Color'])
    
#     if pd.api.types.is_float_dtype(community_color_df['Node']):
#         community_color_df['Node'] = community_color_df['Node'].astype(int)
    
#     return community_color_df

# %%
def plot_community(communities, stations_locs_df, zoom, month, year, time, df_trip=0, heatmap_plt=False):
    '''
    INPUT
    communities        : List of sets containing stations that are grouped based on the communities
    stations_locs_df   : DataFrame containing the stations and their location coordinates
    zoom 
    month
    year
    time
    df_trip 
    
    OUTPUT
    community_color_df : DataFrame mapping each node to its community and color
    map_boston         : Folium map object with plotted stations and their communities
    '''

    map_center_latitude = stations_locs_df['latitude'].mean()
    map_center_longitude = stations_locs_df['longitude'].mean()

    # Use the function to create the community color DataFrame if the input is not already the processed DataFrame 
    if isinstance(communities, pd.DataFrame):
        community_color_df = communities 

    else:
        community_color_df = create_community_color_df(communities, colors)  
    
    node_to_color = community_color_df.set_index('Node')['Color'].to_dict()

    # Create the map
    map_boston = folium.Map(location=[map_center_latitude, map_center_longitude], tiles='CartoDB positron', zoom_start=zoom)

    # Plot the stations, colored by community
    for _, row in stations_locs_df.iterrows():
        station_id = row['station id']
        station_coords = [row['latitude'], row['longitude']]
        station_color = node_to_color.get(station_id, "white")
        
        # Add a marker for the station
        folium.CircleMarker(
            location=station_coords,
            popup=f'Station ID: {station_id}',
            radius=5,
            color=station_color,
            fill=True,
            fill_color=station_color,
            fill_opacity=0.7
        ).add_to(map_boston)
       

    # folium.PolyLine(gal_way, color='red', weight=5, opacity=1).add_to(map_boston)
    # folium.PolyLine(bdwy_str, color='blue', weight=5, opacity=1).add_to(map_boston)
    # folium.PolyLine(beacon_str, color='purple', weight=5, opacity=1).add_to(map_boston)
    folium.PolyLine(cam_str, color='blue', weight=5, opacity=1).add_to(map_boston)
    folium.PolyLine(ox_str, color='orange', weight=5, opacity=1).add_to(map_boston)

    
    # Harvard Square Station
    folium.CircleMarker(
        location=[42.3770, -71.1167],
        radius=6,  # radius is in pixels
        popup='Harvard Square Station',
        color='black',
        fill=True,
        fill_color='black'
    ).add_to(map_boston)
    
    # Porter Square Station
    folium.CircleMarker(
        location=[42.388505, -71.119198],
        radius=6,
        popup='Porter Square Station',
        color='black',
        fill=True,
        fill_color='black'
    ).add_to(map_boston)
    
    # Central Station
    folium.CircleMarker(
        location=[42.365338, -71.103418],
        radius=6,
        popup='Central Station',
        color='black',
        fill=True,
        fill_color='black'
    ).add_to(map_boston)
    
    # Kendall/MIT Station
    folium.CircleMarker(
        location=[42.362400, -71.085570],
        radius=6,
        popup='Kendall/MIT Station',
        color='black',
        fill=True,
        fill_color='black'
    ).add_to(map_boston)
    
    # Alewife Station
    folium.CircleMarker(
        location=[42.395579, -71.142624],
        radius=6,
        popup='Alewife Station',
        color='black',
        fill=True,
        fill_color='black'
    ).add_to(map_boston)

    # Park Street Station
    folium.CircleMarker(
        location=[ 42.356331, -71.062290],
        radius=6,
        popup='Park Street Station',
        color='black',
        fill=True,
        fill_color='black'
    ).add_to(map_boston)

    if heatmap_plt == True:
        heat_data = [[row.iloc[1], row.iloc[2], row.iloc[3]] for index, row in df_trip.iterrows()]

        heatmap = HeatMap(heat_data)
        map_boston.add_child(heatmap)

    month_name = datetime.date(year, month, 1).strftime('%b')
    formatted_time = f"{time:02}:00"
    formatted_string = f"{month_name} {year}, {formatted_time}"

    legend_html = f'''
    <div style="position: fixed; 
                top: 30px; right: 50px; width: 170px; height: 40px; 
                border:3px solid grey; z-index:9999; font-size:20px;
                ">&nbsp;{formatted_string}
    </div>
    '''
    map_boston.get_root().html.add_child(folium.Element(legend_html))

    return community_color_df, map_boston

# %%
starth = 9
endh = 10
mon = 9 
year1 = 2016
year2 = 2018

# %%
df_depart_before = trip_counts_16.groupby(['start station id', 'start station latitude', 'start station longitude'])['trip_count'].sum().reset_index()
df_arrive_before = trip_counts_16.groupby(['end station id', 'end station latitude', 'end station longitude'])['trip_count'].sum().reset_index()

comm_col_16, map_16 = plot_community(commun16, stations_loc_16, 11, month = mon, year = year1, time = starth, df_trip = df_depart_before, heatmap_plt=True)
map_16
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c01be9a7fb5678b33349800e04381f67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed;
#                 top: 30px; right: 50px; width: 170px; height: 40px;
#                 border:3px solid grey; z-index:9999; font-size:20px;
#                 &quot;&gt;&amp;nbsp;Sep 2016, 09:00
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c01be9a7fb5678b33349800e04381f67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c01be9a7fb5678b33349800e04381f67 = L.map(
#                 &quot;map_c01be9a7fb5678b33349800e04381f67&quot;,
#                 {
#                     center: [42.354986502754066, -71.08740213355387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5cdf8d501df734aaa0299623ab88fa1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e5cdf8d501df734aaa0299623ab88fa1.addTo(map_c01be9a7fb5678b33349800e04381f67);
#
#
#             var circle_marker_9e63e8f6e7bc843936ca495b976dedcd = L.circleMarker(
#                 [42.340021, -71.100812],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c01be9a7fb5678b33349800e04381f67);
#
#
#         var popup_d495f351130eae7958dc91cf5fdc512a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_57723089852f4b27df9554629ffa8d1c = $(`&lt;div id=&quot;html_57723089852f4b27df9554629ffa8d1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 3.0&lt;/div&gt;`)[0];
#                 popup_d495f351130eae7958dc91cf5fdc512a.setContent(html_57723089852f4b27df9554629ffa8d1c);
#
#
#
#         circle_marker_9e63e8f6e7bc843936ca495b976dedcd.bindPopup(popup_d495f351130eae7958dc91cf5fdc512a)
#         ;
#
#
#
#
#             var circle_marker_827815aec05f28e3ba27bc7af1c0681f = L.circleMarker(
#                 [42.345392, -71.069616],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c01be9a7fb5678b33349800e04381f67);
#
#
#         var popup_12a177fee43826684fe4a825b4bcb7a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bafebb497670d92dae2dfbe941ec4e2a = $(`&lt;div id=&quot;html_bafebb497670d92dae2dfbe941ec4e2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 4.0&lt;/div&gt;`)[0];
#                 popup_12a177fee43826684fe4a825b4bcb7a3.setContent(html_bafebb497670d92dae2dfbe941ec4e2a);
#
#
#
#         circle_marker_827815aec05f28e3ba27bc7af1c0681f.bindPopup(popup_12a177fee43826684fe4a825b4bcb7a3)
#         ;
#
#
#
#
#             var circle_marker_c1c6075d441d996e6b724b24cd9eeb00 = L.circleMarker(
#                 [42.341814, -71.090179],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c01be9a7fb5678b33349800e04381f67);
#
#
#         var popup_1d49a943c9212efdb5e7f2dcb9df2aec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1998f20263766497238bc6bce5375e09 = $(`&lt;div id=&quot;html_1998f20263766497238bc6bce5375e09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 5.0&lt;/div&gt;`)[0];
#                 popup_1d49a943c9212efdb5e7f2dcb9df2aec.setContent(html_1998f202637664972

# %%
df_depart_after = trip_counts_18.groupby(['start station id', 'start station latitude', 'start station longitude'])['trip_count'].sum().reset_index()
df_arrive_after = trip_counts_18.groupby(['end station id', 'end station latitude', 'end station longitude'])['trip_count'].sum().reset_index()

comm_col_18, map_18 = plot_community(commun18, stations_loc_18, 11, month = mon, year = year1, time = starth, df_trip = df_depart_before, heatmap_plt=True)
map_18
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d339c847451430600c36edd78994aa8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed;
#                 top: 30px; right: 50px; width: 170px; height: 40px;
#                 border:3px solid grey; z-index:9999; font-size:20px;
#                 &quot;&gt;&amp;nbsp;Sep 2016, 09:00
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d339c847451430600c36edd78994aa8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d339c847451430600c36edd78994aa8d = L.map(
#                 &quot;map_d339c847451430600c36edd78994aa8d&quot;,
#                 {
#                     center: [42.35304834363527, -71.08868017513646],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bcc3adc54a71b1acfa60904ede7bbee0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bcc3adc54a71b1acfa60904ede7bbee0.addTo(map_d339c847451430600c36edd78994aa8d);
#
#
#             var circle_marker_a8ba43eb1d09dedaa5815f12600d69aa = L.circleMarker(
#                 [42.387151, -71.075978],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d339c847451430600c36edd78994aa8d);
#
#
#         var popup_01cb9140e06f77ceab365e4baf7b6dae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a62a6c745c93542e7aaf6c8fab7592f = $(`&lt;div id=&quot;html_6a62a6c745c93542e7aaf6c8fab7592f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 1.0&lt;/div&gt;`)[0];
#                 popup_01cb9140e06f77ceab365e4baf7b6dae.setContent(html_6a62a6c745c93542e7aaf6c8fab7592f);
#
#
#
#         circle_marker_a8ba43eb1d09dedaa5815f12600d69aa.bindPopup(popup_01cb9140e06f77ceab365e4baf7b6dae)
#         ;
#
#
#
#
#             var circle_marker_02519c0a0602687aa77dc4a7a4e46cd8 = L.circleMarker(
#                 [42.34011512249236, -71.10061883926392],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d339c847451430600c36edd78994aa8d);
#
#
#         var popup_43f85eab13b3af84a4f3abdd335396b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d536dd71b882e22ec309c38ed3185e8a = $(`&lt;div id=&quot;html_d536dd71b882e22ec309c38ed3185e8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 3.0&lt;/div&gt;`)[0];
#                 popup_43f85eab13b3af84a4f3abdd335396b0.setContent(html_d536dd71b882e22ec309c38ed3185e8a);
#
#
#
#         circle_marker_02519c0a0602687aa77dc4a7a4e46cd8.bindPopup(popup_43f85eab13b3af84a4f3abdd335396b0)
#         ;
#
#
#
#
#             var circle_marker_5e8dd34f6ec9bed1fd4667b9fc739ea8 = L.circleMarker(
#                 [42.345392, -71.069616],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d339c847451430600c36edd78994aa8d);
#
#
#         var popup_4e1123a6ce088bc70fae5c521682e966 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af47c5a9d8d18ae4f610520ca4a96f6e = $(`&lt;div id=&quot;html_af47c5a9d8d18ae4f610520ca4a96f6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 4.0&lt;/div&gt;`)[0];
#                 popup_4e1123a6ce088bc70fae5c521682e966.setContent(htm

# %%
print('The number of communities are changing by', len(commun18)- len(commun16))
# Out:
# The number of communities are changing by 3

# %% [markdown]
# ### Make loop to make a comparison analysis per hour of same month

# %%
mm = 9
yy = 2016
sh = 19
eh = 20
data_18, trip_counts_18, stations_loc_18 = initial_cleaning (month = mm, year = yy, start_hour = sh, end_hour = eh)
BSN18, UNDIR18, adj18 = create_network(trip_counts_18, stations_loc_18, plot=False)
if  (adj18.sum().sum() == len(data_18)):
    bmod18, bres18, commun18 = com_finder(BSN18, resolutions_range = [1], plot=False)
    comm_col_18, map_18 = plot_community(commun18, stations_loc_18, 11, month = mm, year = yy, time = sh)
map_18
# Out:
# 201609-hubway-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.36
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e5deec081a02a3982e466f632795cdd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed;
#                 top: 30px; right: 50px; width: 170px; height: 40px;
#                 border:3px solid grey; z-index:9999; font-size:20px;
#                 &quot;&gt;&amp;nbsp;Sep 2016, 19:00
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e5deec081a02a3982e466f632795cdd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e5deec081a02a3982e466f632795cdd = L.map(
#                 &quot;map_3e5deec081a02a3982e466f632795cdd&quot;,
#                 {
#                     center: [42.3547515293584, -71.0873590695465],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d87cfc13b245b403b113dde2db02246 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2d87cfc13b245b403b113dde2db02246.addTo(map_3e5deec081a02a3982e466f632795cdd);
#
#
#             var circle_marker_e9a8de8df89223d18d39a622546673b1 = L.circleMarker(
#                 [42.387151, -71.075978],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e5deec081a02a3982e466f632795cdd);
#
#
#         var popup_abd3fff192431a681ec650a984c2c4a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf8cd7a8a44292a3cc758edbfe379155 = $(`&lt;div id=&quot;html_cf8cd7a8a44292a3cc758edbfe379155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 1.0&lt;/div&gt;`)[0];
#                 popup_abd3fff192431a681ec650a984c2c4a7.setContent(html_cf8cd7a8a44292a3cc758edbfe379155);
#
#
#
#         circle_marker_e9a8de8df89223d18d39a622546673b1.bindPopup(popup_abd3fff192431a681ec650a984c2c4a7)
#         ;
#
#
#
#
#             var circle_marker_48a0b0b925b7b40dfe8a281857eef4f5 = L.circleMarker(
#                 [42.340021, -71.100812],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e5deec081a02a3982e466f632795cdd);
#
#
#         var popup_c22ada5fa462d6675b00188d27fe0e77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2057af9593c70c6d536bbded1c4fdfba = $(`&lt;div id=&quot;html_2057af9593c70c6d536bbded1c4fdfba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 3.0&lt;/div&gt;`)[0];
#                 popup_c22ada5fa462d6675b00188d27fe0e77.setContent(html_2057af9593c70c6d536bbded1c4fdfba);
#
#
#
#         circle_marker_48a0b0b925b7b40dfe8a281857eef4f5.bindPopup(popup_c22ada5fa462d6675b00188d27fe0e77)
#         ;
#
#
#
#
#             var circle_marker_b26224b667d22e1c95ae76367efef4d4 = L.circleMarker(
#                 [42.345392, -71.069616],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e5deec081a02a3982e466f632795cdd);
#
#
#         var popup_4e08f2bfb5888129970ff61bae1b45dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b07c1f031b0a13eb372bfd84854008e6 = $(`&lt;div id=&quot;html_b07c1f031b0a13eb372bfd84854008e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 4.0&lt;/div&gt;`)[0];
#                 popup_4e08f2bfb5888129970ff61bae1b45dd.setContent(html_b07c1f031b0a13eb372bfd84854008e6);
#
#
#
#         circle_marker_b26224b667d22e1c95ae76367efef4d4.bindPopup(popup_4e08f2bfb5888129970ff61bae1b45dd)

# %%
stations_loc_18[stations_loc_18['station id']==108]
# Out:
#     station id   latitude  longitude
# 98         108  42.377945 -71.116865

# %% [markdown]
# ## Analysis 2 -- Streets effects on the trips between stations that have a high chance on passing

# %% [markdown]
# - Cambridge Street
#
# In this case, the stations on the right side of the street are 88, 95, and 225 (for 2018) , while the stations on the left are 89, 104, 110 and 108. Particular interest are the trips that happened between these 2 sections.
#
# - Oxford Street
#
# In this case, the stations on the south side of the street are 110 and 108 , while the stations on the north are 99, 176, 115. Particular interest are the trips that happened between these 2 sections.

# %%
print(' The number of trips total changes by', np.sum(trip_counts_18['trip_count'])-np.sum(trip_counts_16['trip_count']))
# Out:
#  The number of trips total changes by -78

# %%
sect_1 = [88,95,225]
sect_2 = [89,104,108,110]
sect_3 = [110,108]
sect_4 = [99,115,176]

trip_sect1_16 = data_16.loc[data_16['start station id'].isin(sect_1 [:2]) & data_16['end station id'].isin(sect_2)]
trip_sect2_16 = data_16.loc[data_16['start station id'].isin(sect_2) & data_16['end station id'].isin(sect_1 [:2])]
trip_sect3_16 = data_16.loc[data_16['start station id'].isin(sect_4) & data_16['end station id'].isin(sect_3)]
trip_sect4_16 = data_16.loc[data_16['start station id'].isin(sect_3) & data_16['end station id'].isin(sect_4)]

trip_sect1_18 = data_18.loc[data_18['start station id'].isin(sect_1) & data_18['end station id'].isin(sect_2)]
trip_sect2_18 = data_18.loc[data_18['start station id'].isin(sect_2) & data_18['end station id'].isin(sect_1)]
trip_sect3_18 = data_18.loc[data_18['start station id'].isin(sect_4) & data_18['end station id'].isin(sect_3)]
trip_sect4_18 = data_18.loc[data_18['start station id'].isin(sect_3) & data_18['end station id'].isin(sect_4)]

# %%
## Number of trips analysis 
trip_sect_16 = len(trip_sect1_16)+len(trip_sect2_16)+len(trip_sect3_16)+len(trip_sect4_16)
trip_sect_18 = len(trip_sect1_18)+len(trip_sect2_18)+len(trip_sect3_18)+len(trip_sect4_18)
dif_trip = trip_sect_18 - trip_sect_16
print('The total number of trip changes by', dif_trip ,'trips')
# Out:
# The total number of trip changes by -11 trips

# %%
a1 = trip_sect1_16.groupby(['start station id', 'end station id'])['tripduration'].mean().reset_index().astype(int)
a2 = trip_sect2_16.groupby(['start station id', 'end station id'])['tripduration'].mean().reset_index().astype(int)
a3 = trip_sect3_16.groupby(['start station id', 'end station id'])['tripduration'].mean().reset_index().astype(int)
a4 = trip_sect4_16.groupby(['start station id', 'end station id'])['tripduration'].mean().reset_index().astype(int)
td16 =  pd.concat([a1,a2,a3,a4], ignore_index=True)
td16.rename(columns={'tripduration': 'avg duration 16'}, inplace=True)


b1 = trip_sect1_18.groupby(['start station id', 'end station id'])['tripduration'].mean().reset_index().astype(int)
b2 = trip_sect2_18.groupby(['start station id', 'end station id'])['tripduration'].mean().reset_index().astype(int)
b3 = trip_sect3_18.groupby(['start station id', 'end station id'])['tripduration'].mean().reset_index().astype(int)
b4 = trip_sect4_18.groupby(['start station id', 'end station id'])['tripduration'].mean().reset_index().astype(int)
td18 =  pd.concat([b1,b2,b3,b4], ignore_index=True)
td18.rename(columns={'tripduration': 'avg duration 18'}, inplace=True)

# %%
td = pd.merge(td16, td18, on=['start station id', 'end station id'], how='outer')
td['avg duration 16'] = td['avg duration 16'].fillna(0)
td['avg duration 18'] = td['avg duration 18'].fillna(0)

# Only count the changes when then trips exist before and after the street 
td['changes_duration'] = td.apply(
    lambda row: row['avg duration 16'] - row['avg duration 18']
    if row['avg duration 16'] > 0 and row['avg duration 18'] > 0 else 0, axis=1
)
td
# Out:
#     start station id  end station id  avg duration 16  avg duration 18  \
# 0                 88              89            658.0              0.0
# 1                 88             108            487.0              0.0
# 2                 88             110            284.0            324.0
# 3                 89              88              0.0            681.0
# 4                 89              95              0.0            538.0
# 5                 95             108            536.0              0.0
# 6                 95             110            463.0            406.0
# 7                 99             108            357.0              0.0
# 8                 99             110            540.0            511.0
# 9                104              88              0.0            731.0
# 10               104              95            982.0              0.0
# 11               108              88              0.0            455.0
# 12               108              99              0.0            392.0
# 13               108             115              0.0            332.0
# 14               108             176            326.0              0.0
# 15               110              88            377.0            334.0
# 16               110              95              0.0            839.0
# 17               110              99              0.0            480.0
# 18               110             115              0.0            425.0
# 19               110             176              0.0            550.0
# 20               115             108            506.0              0.0
# 21               115             110            459.0            621.0
# 22               176             108              0.0            409.0
#
#     changes_duration
# 0                0.0
# 1                0.0
# 2              -40.0
# 3                0.0
# 4                0.0
# 5                0.0
# 6               57.0
# 7                0.0
# 8               29.0
# 9                0.0
# 10               0.0
# 11               0.0
# 12               0.0
# 13               0.0
# 14               0.0
# 15              43.0
# 16               0.0
# 17               0.0
# 18               0.0
# 19               0.0
# 20               0.0
# 21            -162.0
# 22               0.0

# %%
print('Total duration changes on the trips are', np.round(np.sum(td['changes_duration'])/sum(td['changes_duration']!=0),2), 'seconds')
# Out:
# Total duration changes on the trips are -14.6 seconds

# %% [markdown]
# ## Partial Functions

# %%
def the_spots(coordinate, num_stats, stations_loc):
    '''
    INPUT
    coordinate   : Array of (latitude,longitude)
    num_stats    : Integer corresponds to the number of stations closest to the target streets
    stations_loc : Dataframe containing the stations and its location coordinates
    
    OUTPUT 
    stationz = the name of the closest stations to the coordinnate
    '''
    d1 = np.array([stations_loc['latitude'], stations_loc['longitude']]).T - coordinate.reshape(1, 2)
    dst = np.linalg.norm(d1, axis=1)
    idx_closest = np.argsort(dst)[:num_stats]
    stationz = stations_loc.iloc[idx_closest]['station id'].tolist()
            
    return stationz

# %%
def partial_graph_data(closest_stations, trip_counts_df, station_locs_df, community_color_df):
    '''
    INPUT
    closest_stations   : List of closest stations to the target street
    trip_count_df      : Dataframe containing the start station, end station, and trip count 
    stations_loc       : Dataframe containing information about the latitude and longitude of each stations 
    community_color_df : DataFrame mapping each node to its community and color


    OUTPUT 
    trips_spot           : Dataframe containing the information regarding the trips between the closests stations
    stations_loc_partial : Dataframe containing the information about the latitude and longitude of each closests stations 
    partial              : Directed graph of the closest stations
    com_partial_df       : Dataframe containing the information about the community and the colors of the closest stations
    '''
    
    trips_spot = trip_counts_df[(trip_counts_df['start station id'].isin(closest_stations)) & (trip_counts_df['end station id'].isin(closest_stations))].reset_index(drop=True)
    stat_loc_spot = station_locs_df[(station_locs_df['station id'].isin(closest_stations)) & (station_locs_df['station id'].isin(closest_stations))].reset_index(drop=True)
    com_partial_df = community_color_df[(community_color_df['Node'].isin(closest_stations))].reset_index(drop=True)
    
    # Make the graph
    partial = nx.DiGraph()
    for _, row in trips_spot.iterrows():
        partial.add_edge((row['start station id']), (row['end station id']), weight=(row['trip_count']))
            
    return trips_spot, stat_loc_spot, partial, com_partial_df

# %% [markdown]
# ## Test Jaccard Index

# %%
from scipy.optimize import minimize

# %%
def jaccard_index(set1, set2):
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    if not union:
        return 0.0
    return len(intersection) / len(union)

# %%
def geometric_median(coords):
    """
    Compute the geometric median of a numpy array of coordinates.
    """
    def L1_norm(x):
        return np.sum(np.linalg.norm(coords - x, axis=1))

    # Initial guess: simply use the mean
    initial_guess = np.mean(coords, axis=0)

    result = minimize(L1_norm, initial_guess, method='BFGS')
    return result.x

def calculate_center_of_mass(df):
    """ Calculate the geometric center for each community based on longitude and latitude. """
    centroids = df.groupby('Community').apply(
        lambda g: geometric_median(g[['longitude', 'latitude']].values),
        include_groups=False  # Add this parameter to comply with future pandas updates
    )
    return centroids.to_dict()


def find_closest_anchor(center_of_mass, anchors):
    """ Find the closest anchor to a given center of mass. """
    closest = min(anchors, key=lambda x: np.linalg.norm(np.array(center_of_mass) - np.array((x['Longitude'], x['Latitude']))))
    return closest['Community'], closest['Color']

def assign_colors_based_on_proximity(centroids, anchors, available_colors):
    # Step 1: Calculate distances from each community to each anchor
    distances = {}
    for comm, center in centroids.items():
        for anchor_id, anchor_details in anchors.items():
            if comm not in distances:
                distances[comm] = {}
            distances[comm][anchor_id] = np.linalg.norm(np.array(center) - np.array((anchor_details['Longitude'], anchor_details['Latitude'])))

    # Step 2: Determine the closest community for each anchor
    closest_communities = {}
    for anchor_id in anchors:
        closest_community = min(distances, key=lambda x: distances[x][anchor_id])
        closest_communities[closest_community] = anchor_id

    # Step 3: Assign anchor colors to closest communities and other colors to the rest
    color_mapping = {}
    used_colors = set()
    for comm, anchor_id in closest_communities.items():
        anchor_color = anchors[anchor_id]['Color']
        color_mapping[comm] = anchor_color
        used_colors.add(anchor_color)

    # Ensure unique colors for other communities
    remaining_colors = [color for color in available_colors if color not in used_colors]
    color_iter = iter(remaining_colors)
    for comm in centroids:
        if comm not in color_mapping:
            try:
                color_mapping[comm] = next(color_iter)
            except StopIteration:
                # Reset iterator if there are more communities than remaining colors
                color_iter = iter(remaining_colors)
                color_mapping[comm] = next(color_iter)

    return color_mapping
    
def enhanced_color_assignment(previous_df, current_df, available_colors, anchors):

    previous_communities = {k: set(g['Node']) for k, g in previous_df.groupby('Community')}
    current_communities = {k: set(g['Node']) for k, g in current_df.groupby('Community')}
    community_sizes = {k: len(v) for k, v in current_communities.items()}
    
    mapping = {}
    jaccard_scores = {}
    for current, current_set in current_communities.items():
        best_match = None
        highest_jaccard = 0
        for previous, previous_set in previous_communities.items():
            j_index = jaccard_index(current_set, previous_set)
            if j_index > highest_jaccard:
                highest_jaccard = j_index
                best_match = previous
        mapping[current] = best_match
        jaccard_scores[current] = highest_jaccard

    reverse_mapping = {prev: [] for prev in previous_communities.keys()}
    for cur, prev in mapping.items():
        if prev is not None:
            reverse_mapping[prev].append(cur)

    # Calculate centers of mass
    previous_centroids = calculate_center_of_mass(previous_df)
    current_centroids = calculate_center_of_mass(current_df)
    
    color_mapping = {}
    used_colors = set(previous_df['Color'])
    available_color_iter = iter(available_colors)

    for prev, cur_list in reverse_mapping.items():
        color_mapping.update(assign_colors_based_on_proximity(current_centroids, anchors, available_colors))

    # Assign new colors to new communities or unassigned communities
    for cur in current_communities.keys():
        if cur not in color_mapping:
            color_mapping[cur] = next(available_color_iter, 'Fallback Color')

    current_df['Color'] = current_df['Community'].map(color_mapping)

    return current_df

# %%
def update_available_colors(previous_df):
    # all_colors = [
    #     'red', 'blue', 'green', 'yellow', 'purple', 'orange', 'pink', 'gray', 'brown', 'cyan',
    #     'magenta', 'lime', 'maroon', 'olive', 'navy', 'teal', 'aqua', 'fuchsia', 'silver'
    # ]
    all_colors = [ 'yellow', 'gray', 'brown', 'cyan',
     'magenta', 'lime', 'maroon', 'olive', 'navy', 'teal', 'aqua', 'fuchsia']
    used_colors = set(previous_df['Color'])
    available_colors = [color for color in all_colors if color not in used_colors]
    return available_colors

# %%
anchors = {
    1: {'Longitude': -71.095993,
        'Latitude': 42.360839,
        'Color': 'red',
        'Community': int(0)  
    },
    2: {
        'Longitude':  -71.116865,
        'Latitude': 42.377945,
        'Color': 'green',
        'Community': int(1) 
    },

        3: {
        'Longitude': -71.126533,
        'Latitude': 42.402038,
        'Color': 'purple',
        'Community': int(2) 
    },

    #     4: {
    #     'Longitude': -71.069616,
    #     'Latitude': 42.345392,
    #     'Color': 'blue',
    #     'Community': int(3) 
    # },    

        # 5: {
        # 'Longitude': -71.105221,
        # 'Latitude': 42.334073,
        # 'Color': 'orange',
        # 'Community': int(4) 
    # },
    #         6: {
    #     'Longitude': -71.016273,
    #     'Latitude':42.386649,
    #     'Color': 'pink',
    #     'Community': int(5) 
    # }
}

# %%
all_colors = [  'red', 'blue', 'green', 'yellow', 'purple', 'orange', 'pink', 'gray', 'brown', 'cyan',
    'magenta', 'lime', 'maroon', 'olive', 'navy', 'teal', 'aqua', 'fuchsia']

# %%
# Define a dictionary to store your maps
maps = {}

mm = 9
yy = 2018

# Assume you have a function to determine hours range or specific hours list
hours = range(6, 23)  # Example: from 7 AM to 8 PM, adjust according to your actual data

for index, hour in enumerate(hours):

    # Generate data for each hour
    data_18, trip_counts_18, stations_loc_18 = initial_cleaning(month=mm, year=yy, start_hour=hour, end_hour=hour+1)
    closest_stations_1 =  the_spots(np.array(cam_str[0]), 50, stations_loc_18)
    closest_stations_2 =  the_spots(np.array(cam_str[-1]), 50, stations_loc_18)
    closest_stations_3 =  the_spots(np.array(ox_str[0]), 50, stations_loc_18)
    closest_stations_4 =  the_spots(np.array(ox_str[-1]), 50, stations_loc_18)
    closest_stations_18 = list(set(closest_stations_1 + closest_stations_2 + closest_stations_3 + closest_stations_4))
    # closest_stations_18 = list(set(closest_stations_1 + closest_stations_3))

    closest_stations_18 = sorted(closest_stations_18)

    partial_df_18, loc_partial_18, partial_nw_18, com_partial_18 = partial_graph_data(closest_stations_18, trip_counts_18, stations_loc_18, comm_col_18)
    df_depart_ptaf = partial_df_18.groupby(['start station id', 'start station latitude', 'start station longitude'])['trip_count'].sum().reset_index()
    df_arrive_ptaf = partial_df_18.groupby(['end station id', 'end station latitude', 'end station longitude'])['trip_count'].sum().reset_index()
    adj_as = pd.DataFrame(nx.adjacency_matrix(partial_nw_18).todense().astype(int), index=partial_nw_18.nodes(), columns=partial_nw_18.nodes())

    if (adj_as.sum().sum() == np.sum(partial_df_18['trip_count'])):
        bmod18, bres18, commun18 = com_finder(partial_nw_18, resolutions_range=[1], plot=False)
        
        if index == 0:
            d1 = create_community_color_df(commun18, colors) 
            d1  = pd.merge(d1, loc_partial_18, right_on='station id', left_on='Node', how='inner')
            centroids = calculate_center_of_mass(d1)
            color_mapping = assign_colors_based_on_proximity(centroids, anchors, all_colors)
            d1['Color'] = d1['Community'].map(color_mapping)
            comm_col_182, map_html = plot_community(d1, loc_partial_18, 12, month = mm, year = yy, time = hour, df_trip = df_arrive_ptaf, heatmap_plt=True)

        else:
            com_col_now = create_community_color_df(commun18, colors) 
            com_col_now  = pd.merge(com_col_now, loc_partial_18, right_on='station id', left_on='Node', how='inner')
            ss = enhanced_color_assignment(com_col_prev, com_col_now, update_available_colors(com_col_prev),anchors)
            comm_col_182, map_html = plot_community(ss, loc_partial_18, 12, month = mm, year = yy, time = hour, df_trip = df_arrive_ptaf, heatmap_plt=True)
        
        

        com_col_prev = 0
        com_col_prev = comm_col_182 
        comm_col_182 = 0

        # Save map
        result_folder = "result"
        os.makedirs(result_folder, exist_ok=True)
        map_file = os.path.join(result_folder, f"map_hour_{hour}_mon_{mm}_year_{yy}.html")
        map_html.save(map_file)
        map_html.save(map_file)
        maps[hour] = map_file
# Out:
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.46
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.33
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.26
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.28
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.29
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.29
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.32
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.32
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.29
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.3
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.29
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.26
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.26
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.28
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.27
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.27
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.29

# %%
# Output widgets for controls and the map display
controls_output = widgets.Output()
map_output = widgets.Output()

def generate_map(hour):
    # Clear and update the map display within the map_output widget
    with map_output:
        clear_output(wait=True)
        map_file = os.path.join(result_folder, f"map_hour_{hour}.html")
        display(IFrame(map_file, width='100%', height='500px'))

# Slider and buttons setup
slider = widgets.IntSlider(min=min(hours), max=max(hours), step=1, value=6, description='Hour:')
slider.observe(lambda change: generate_map(change['new']), 'value')

# Display the controls in the controls_output widget
with controls_output:
    display(slider)

# Initial display setup

display(controls_output, map_output)
generate_map(slider.value)
# Out:
# Output()
# Output()

# %%
hti = Html2Image()

for hour, map_file in maps.items():
    img_path = f"map_{hour}.png"
    hti.screenshot(html_file=map_file, save_as=img_path)
    maps[hour] = img_path

# %%
import imageio.v2 as imageio
filenames = [maps[hour] for hour in sorted(maps.keys())]

images = [imageio.imread(filename) for filename in filenames]
duration_set = 500 
imageio.mimsave('maps_animation9_after.gif', images, duration=duration_set)

# %%
import imageio
# writer = imageio.get_writer('maps_animation9_after.mp4', fps=2, macro_block_size=1)
writer = imageio.get_writer('ori.mp4', fps=2, macro_block_size=1)

for image in images:
    writer.append_data(image)
writer.close()

# %% [markdown]
# ## Stash

# %%
# # Define a dictionary to store your maps
# maps = {}

# mm = 9
# yy = 2018

# # Assume you have a function to determine hours range or specific hours list
# hours = range(6, 23)  # Example: from 7 AM to 8 PM, adjust according to your actual data

# for hour in hours:
#     # Generate data for each hour
#     data_18, trip_counts_18, stations_loc_18 = initial_cleaning(month=mm, year=yy, start_hour=hour, end_hour=hour+1)
#     closest_stations_1 =  the_spots(np.array(cam_str[0]), 1000, stations_loc_18)
#     closest_stations_2 =  the_spots(np.array(cam_str[-1]), 1000, stations_loc_18)
#     closest_stations_3 =  the_spots(np.array(ox_str[0]), 1000, stations_loc_18)
#     closest_stations_4 =  the_spots(np.array(ox_str[-1]), 1000, stations_loc_18)
#     closest_stations_18 = list(set(closest_stations_1 + closest_stations_2 + closest_stations_3 + closest_stations_4))
#     # closest_stations_18 = list(set(closest_stations_1 + closest_stations_3))

#     closest_stations_18 = sorted(closest_stations_18)

#     partial_df_18, loc_partial_18, partial_nw_18, com_partial_18 = partial_graph_data(closest_stations_18, trip_counts_18, stations_loc_18, comm_col_18)
#     df_depart_ptaf = partial_df_18.groupby(['start station id', 'start station latitude', 'start station longitude'])['trip_count'].sum().reset_index()
#     df_arrive_ptaf = partial_df_18.groupby(['end station id', 'end station latitude', 'end station longitude'])['trip_count'].sum().reset_index()
#     adj_as = pd.DataFrame(nx.adjacency_matrix(partial_nw_18).todense().astype(int), index=partial_nw_18.nodes(), columns=partial_nw_18.nodes())

#     if (adj_as.sum().sum() == np.sum(partial_df_18['trip_count'])):
#         bmod18, bres18, commun18 = com_finder(partial_nw_18, resolutions_range=[1], plot=False)
#         comm_col_182, map_html = plot_community(commun18, loc_partial_18, 11, month = mm, year = yy, time = hour)#, df_trip = df_arrive_ptaf, heatmap_plt=True)
        
#         # Save the map to HTML and store reference
#         map_file = f"map_{hour}.html"
#         map_html.save(map_file)
#         maps[hour] = map_file

# %%
# def find_most_similar_and_update_color(previous_df, current_df, available_colors):

#     # Prepare community sets
#     previous_communities = {k: set(g['Node']) for k, g in previous_df.groupby('Community')}
#     current_communities = {k: set(g['Node']) for k, g in current_df.groupby('Community')}
#     community_sizes = {k: len(v) for k, v in current_communities.items()}

#     # Track mappings and scores
#     mapping = {}
#     jaccard_scores = {}

#     # Find matches based on Jaccard index
#     for current, current_set in current_communities.items():
#         best_match = None
#         highest_jaccard = 0
#         for previous, previous_set in previous_communities.items():
#             j_index = jaccard_index(current_set, previous_set)
#             if j_index > highest_jaccard:
#                 highest_jaccard = j_index
#                 best_match = previous
#         mapping[current] = best_match
#         jaccard_scores[current] = highest_jaccard

#     # Handle community splits and merges
#     reverse_mapping = {prev: [] for prev in previous_communities.keys()}
#     for cur, prev in mapping.items():
#         if prev is not None:
#             reverse_mapping[prev].append(cur)

#     # Assign new colors and manage splits
#     color_mapping = {}
#     used_colors = set(previous_df['Color'])
#     available_color_iter = iter(available_colors)

#     for prev, cur_list in reverse_mapping.items():
#         if len(cur_list) > 1:  # Community was split
#             sizes = {cur: community_sizes[cur] for cur in cur_list}
#             major_community = max(sizes, key=sizes.get)
#             major_color = previous_df[previous_df['Community'] == prev]['Color'].iloc[0]
#             color_mapping[major_community] = major_color
#             for cur in cur_list:
#                 if cur != major_community:
#                     color_mapping[cur] = next(available_color_iter, 'Fallback Color')
#         else:
#             # Assign color of previous community to current
#             if cur_list:  # To handle empty lists
#                 color_mapping[cur_list[0]] = previous_df[previous_df['Community'] == prev]['Color'].iloc[0]

#     # Handle new communities or unassigned nodes
#     for cur in current_communities.keys():
#         if cur not in color_mapping:
#             color_mapping[cur] = next(available_color_iter, 'Fallback Color')

#     # Update colors in the current dataframe
#     current_df['Color'] = current_df['Community'].map(color_mapping)

#     return current_df

# %%
s =  enhanced_color_assignment(comm_col_187, comm_col_188, update_available_colors(comm_col_187), anchors)
comm_col_189, map_18r = plot_community(s, loc_partial_188, 11, month = mm, year = yy, time = sh)
map_18r
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86747c891cb037a3f66e1dfa1d0425d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed;
#                 top: 30px; right: 50px; width: 170px; height: 40px;
#                 border:3px solid grey; z-index:9999; font-size:20px;
#                 &quot;&gt;&amp;nbsp;Sep 2018, 12:00
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86747c891cb037a3f66e1dfa1d0425d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86747c891cb037a3f66e1dfa1d0425d8 = L.map(
#                 &quot;map_86747c891cb037a3f66e1dfa1d0425d8&quot;,
#                 {
#                     center: [42.37565515573737, -71.11053790712505],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_356dd91a6ec408e38d3e03e4e741a881 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_356dd91a6ec408e38d3e03e4e741a881.addTo(map_86747c891cb037a3f66e1dfa1d0425d8);
#
#
#             var circle_marker_765b0f31d5c1d615172712bd4ce1e976 = L.circleMarker(
#                 [42.35169201885973, -71.11903488636017],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86747c891cb037a3f66e1dfa1d0425d8);
#
#
#         var popup_f3d9d781fca29cc3afc02ec36abcc196 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_45f49b7e9efec4cfb129f40660914681 = $(`&lt;div id=&quot;html_45f49b7e9efec4cfb129f40660914681&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 9.0&lt;/div&gt;`)[0];
#                 popup_f3d9d781fca29cc3afc02ec36abcc196.setContent(html_45f49b7e9efec4cfb129f40660914681);
#
#
#
#         circle_marker_765b0f31d5c1d615172712bd4ce1e976.bindPopup(popup_f3d9d781fca29cc3afc02ec36abcc196)
#         ;
#
#
#
#
#             var circle_marker_10af7454a656b742ffb3633d4fd36722 = L.circleMarker(
#                 [42.350406, -71.108279],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86747c891cb037a3f66e1dfa1d0425d8);
#
#
#         var popup_d18a8d645ef98056de6a7d301ccff2af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7a4fd361ab789ddba531973de2089df = $(`&lt;div id=&quot;html_e7a4fd361ab789ddba531973de2089df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 10.0&lt;/div&gt;`)[0];
#                 popup_d18a8d645ef98056de6a7d301ccff2af.setContent(html_e7a4fd361ab789ddba531973de2089df);
#
#
#
#         circle_marker_10af7454a656b742ffb3633d4fd36722.bindPopup(popup_d18a8d645ef98056de6a7d301ccff2af)
#         ;
#
#
#
#
#             var circle_marker_cc23f4caa918f0f783712c9761f795a5 = L.circleMarker(
#                 [42.36426344063853, -71.1182756971175],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86747c891cb037a3f66e1dfa1d0425d8);
#
#
#         var popup_4f96270bf87b8c88a6d8386cf8bd4648 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5103e747ddfa97589769210188ffae45 = $(`&lt;div id=&quot;html_5103e747ddfa97589769210188ffae45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 17.0&lt;/div&gt;`)[0];
#                 popup_4f96270bf87b8c88a6d8386cf8bd4648.setContent(html_5103e747ddfa97589769210188ffae45);
#
#
#
#         circle_marker_cc23f4caa918f0f783712c9761f795a5.bindPopup(popu

# %% [markdown]
# ### Compare by month

# %%
mm = range(1, 12)
mm
# Out:
# range(1, 12)

# %%
# Define a dictionary to store your maps
maps = {}

mm = range(1, 13)
yy = 2018

hour = 9

for index, mon in enumerate(mm):

    # Generate data for each hour
    data_18, trip_counts_18, stations_loc_18 = initial_cleaning(month=mon, year=yy, start_hour=hour, end_hour=hour+1)
    closest_stations_1 =  the_spots(np.array(cam_str[0]), 50, stations_loc_18)
    closest_stations_2 =  the_spots(np.array(cam_str[-1]), 50, stations_loc_18)
    closest_stations_3 =  the_spots(np.array(ox_str[0]), 50, stations_loc_18)
    closest_stations_4 =  the_spots(np.array(ox_str[-1]), 50, stations_loc_18)
    closest_stations_18 = list(set(closest_stations_1 + closest_stations_2 + closest_stations_3 + closest_stations_4))
    # closest_stations_18 = list(set(closest_stations_1 + closest_stations_3))

    closest_stations_18 = sorted(closest_stations_18)

    partial_df_18, loc_partial_18, partial_nw_18, com_partial_18 = partial_graph_data(closest_stations_18, trip_counts_18, stations_loc_18, comm_col_18)
    df_depart_ptaf = partial_df_18.groupby(['start station id', 'start station latitude', 'start station longitude'])['trip_count'].sum().reset_index()
    df_arrive_ptaf = partial_df_18.groupby(['end station id', 'end station latitude', 'end station longitude'])['trip_count'].sum().reset_index()
    adj_as = pd.DataFrame(nx.adjacency_matrix(partial_nw_18).todense().astype(int), index=partial_nw_18.nodes(), columns=partial_nw_18.nodes())

    if (adj_as.sum().sum() == np.sum(partial_df_18['trip_count'])):
        bmod18, bres18, commun18 = com_finder(partial_nw_18, resolutions_range=[1], plot=False)
        
        if index == 0:
            d1 = create_community_color_df(commun18, colors) 
            d1  = pd.merge(d1, loc_partial_18, right_on='station id', left_on='Node', how='inner')
            centroids = calculate_center_of_mass(d1)
            color_mapping = assign_colors_based_on_proximity(centroids, anchors, all_colors)
            d1['Color'] = d1['Community'].map(color_mapping)
            comm_col_182, map_html = plot_community(d1, loc_partial_18, 11, month = mon, year = yy, time = hour)#, df_trip = df_arrive_ptaf, heatmap_plt=True)

        else:
            com_col_now = create_community_color_df(commun18, colors) 
            com_col_now  = pd.merge(com_col_now, loc_partial_18, right_on='station id', left_on='Node', how='inner')
            ss = enhanced_color_assignment(com_col_prev, com_col_now, update_available_colors(com_col_prev),anchors)
            comm_col_182, map_html = plot_community(ss, loc_partial_18, 11, month = mon, year = yy, time = hour)#, df_trip = df_arrive_ptaf, heatmap_plt=True)
        
        

        com_col_prev = 0
        com_col_prev = comm_col_182 
        comm_col_182 = 0

        # Save map
        result_folder = "result"
        os.makedirs(result_folder, exist_ok=True)
        map_file = os.path.join(result_folder, f"map_hour_{hour}_mon_{mon}_year_{yy}.html")
        map_html.save(map_file)
        map_html.save(map_file)
        maps[mon] = map_file
# Out:
# 201801-hubway-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.32
# 201802-hubway-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.26
# 201803-hubway-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.31
# 201804-hubway-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.26
# 201805-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.22
# 201806-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.22
# 201807-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.22
# 201808-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.25
# 201809-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.28
# 201810-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.28
# 201811-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.27
# 201812-bluebikes-tripdata.zip already exists.
# Best resolution is on 1 with the value of modularity is 0.28

# %%
def generate_map(hour, mm, yy):
    # Clear and update the map display within the map_output widget
    with map_output:
        clear_output(wait=True)
        map_file = map_file = os.path.join(result_folder, f"map_hour_{hour}_mon_{mon}_year_{yy}.html")
        display(IFrame(map_file, width='100%', height='500px')

# %%
def generate_map(hour, mon, yy):
    with map_output:
        clear_output(wait=True)
        map_file = os.path.join(result_folder, f"map_hour_{hour}_mon_{mon}_year_{yy}.html")
        display(IFrame(map_file, width='100%', height='500px'))

# %%
# Output widgets for controls and the map display
controls_output = widgets.Output()
map_output = widgets.Output()

# Define the range for hour, month, and year
hour_slider = widgets.IntSlider(min=6, max=22, step=1, value=6, description='Hour:')
month_slider = widgets.IntSlider(min=1, max=12, step=1, value=9, description='Month:')
year_text = widgets.IntSlider(min=2016, max=2018, step=2, value=2018, description='Year:')

# Function to update the map based on widget values
def update_map(change):
    generate_map(hour_slider.value, month_slider.value, year_text.value)

# Add observers to update the map when any of the widget values change
hour_slider.observe(update_map, names='value')
month_slider.observe(update_map, names='value')
year_text.observe(update_map, names='value')

# Display the controls in the controls_output widget
with controls_output:
    display(hour_slider, month_slider, year_text)

# Initial display setup
display(controls_output, map_output)
generate_map(hour_slider.value, month_slider.value, year_text.value)
# Out:
# Output()
# Output()

# %%
# Output widgets for controls and the map display
controls_output = widgets.Output()
map_output = widgets.Output()

def generate_map(mm):
    # Clear and update the map display within the map_output widget
    with map_output:
        clear_output(wait=True)
        map_file = os.path.join(result_folder, f"map_mon_{mm}.html")
        display(IFrame(map_file, width='100%', height='500px'))

# Slider and buttons setup
slider = widgets.IntSlider(min=min(mm), max=max(mm), step=1, value=1, description='Month:')
slider.observe(lambda change: generate_map(change['new']), 'value')

# Display the controls in the controls_output widget
with controls_output:
    display(slider)

# Initial display setup

display(controls_output, map_output)
generate_map(slider.value)
# Out:
# Output()
# Output()

# %%
import networkx as nx

# Initialize directed graphs for before and after
G_before = nx.DiGraph()
G_after = nx.DiGraph()

# Add example edges to G_before and G_after
# You should replace these with your actual data
G_before.add_edges_from([('A', 'B'), ('B', 'C'), ('C', 'A')])
G_after.add_edges_from([('A', 'B'), ('B', 'C'), ('C', 'D'), ('D', 'A')])

# Function to calculate average shortest path length for a directed graph
def average_path_length_directed(G):
    length_sum = 0
    count = 0
    for source in G.nodes:
        lengths = nx.single_source_shortest_path_length(G, source)
        for target, length in lengths.items():
            if source != target:
                length_sum += length
                count += 1
    return length_sum / count if count > 0 else float('inf')

avg_path_length_before = average_path_length_directed(G_before)
avg_path_length_after = average_path_length_directed(G_after)

# Ensure there are edges before calculating the clustering coefficient
if len(G_before.edges) > 0:
    clustering_before = nx.average_clustering(G_before.to_undirected())
else:
    clustering_before = 0

if len(G_after.edges) > 0:
    clustering_after = nx.average_clustering(G_after.to_undirected())
else:
    clustering_after = 0

print("Average Path Length Before:", avg_path_length_before)
print("Average Path Length After:", avg_path_length_after)
print("Clustering Coefficient Before:", clustering_before)
print("Clustering Coefficient After:", clustering_after)
# Out:
# Average Path Length Before: 1.5
# Average Path Length After: 2.0
# Clustering Coefficient Before: 1.0
# Clustering Coefficient After: 0.0
